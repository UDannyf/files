# %%
pip install --upgrade gdal
# Out:
# Requirement already satisfied: gdal in /home/danny/anaconda3/lib/python3.9/site-packages (3.3.2)
# Collecting gdal
#   Using cached GDAL-3.6.2.tar.gz (757 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: gdal
#   Building wheel for gdal (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [633 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-39
#       creating build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/gdal.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/gdal_array.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/ogr.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/gdalconst.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/osr.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/__init__.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/gdalnumeric.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       copying osgeo/gnm.py -> build/lib.linux-x86_64-cpython-39/osgeo
#       creating build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal2xyz.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_sieve.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdalcompare.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_calc.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdalattachpct.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_proximity.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/ogr_layer_algebra.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_fillnodata.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_pansharpen.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal2tiles.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdalmove.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_edit.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_merge.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/ogrmerge.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_retile.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/rgb2pct.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/__init__.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/gdal_polygonize.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       copying gdal-utils/osgeo_utils/pct2rgb.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils
#       creating build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/color_table.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/progress.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/numpy_util.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/osr_util.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/util.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/rectangle.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/base.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/gdal_argparse.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/batch_creator.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/color_palette.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/__init__.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/raster_creation.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/extent_util.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       copying gdal-utils/osgeo_utils/auxiliary/array_util.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/auxiliary
#       creating build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogr_build_junction_table.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/tile_extent_from_raster.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/tigerpoly.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/assemblepoly.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/magphase.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/wcs_virtds_params.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/jpeg_in_tiff_extract.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/histrep.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_remove_towgs84.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_zip.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_create_pdf.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/loslas2ntv2.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/build_jp2_from_xml.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gcps2vec.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_cp.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/load2odbc.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/vec_tr.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalcopyproj.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_rm.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/epsg_tr.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalinfo.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/tolatlong.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/validate_cloud_optimized_geotiff.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/rel.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalimport.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_auth.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_rmdir.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/val_repl.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalident.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/crs2crs2grid.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_vrtmerge.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal2grd.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/make_fuzzer_friendly_archive.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalchksum.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/validate_gpkg.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gcps2wld.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_ls.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_mkdir.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/mkgraticule.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/classify.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/vec_tr_spat.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/esri2wkt.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogr2ogr.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogrupdate.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/fft.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdallocationinfo.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/__init__.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gcps2ogr.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/validate_jp2.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/dump_jp2.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdal_lut.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/densify.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/get_soundg.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogr2vrt.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogr_dispatch.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/ogrinfo.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/fix_gpkg.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/gdalfilter.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       copying gdal-utils/osgeo_utils/samples/hsv_merge.py -> build/lib.linux-x86_64-cpython-39/osgeo_utils/samples
#       running build_ext
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c gdal_python_cxx11_test.cpp -o gdal_python_cxx11_test.o
#       building 'osgeo._gdal' extension
#       creating build/temp.linux-x86_64-cpython-39
#       building 'osgeo._gdalconst' extension
#       creating build/temp.linux-x86_64-cpython-39/extensions
#       creating build/temp.linux-x86_64-cpython-39/extensions
#       building 'osgeo._osr' extension
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/osr_wrap.cpp -o build/temp.linux-x86_64-cpython-39/extensions/osr_wrap.o -I/home/danny/anaconda3/include
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/gdalconst_wrap.c -o build/temp.linux-x86_64-cpython-39/extensions/gdalconst_wrap.o -I/home/danny/anaconda3/include
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/gdal_wrap.cpp -o build/temp.linux-x86_64-cpython-39/extensions/gdal_wrap.o -I/home/danny/anaconda3/include
#       building 'osgeo._ogr' extension
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/ogr_wrap.cpp -o build/temp.linux-x86_64-cpython-39/extensions/ogr_wrap.o -I/home/danny/anaconda3/include
#       extensions/ogr_wrap.cpp:2851:10: fatal error: ogr_recordbatch.h: No existe el archivo o el directorio
#        2851 | #include "ogr_recordbatch.h"
#             |          ^~~~~~~~~~~~~~~~~~~
#       compilation terminated.
#       building 'osgeo._gnm' extension
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/gnm_wrap.cpp -o build/temp.linux-x86_64-cpython-39/extensions/gnm_wrap.o -I/home/danny/anaconda3/include
#       extensions/gdalconst_wrap.c: In function ‘PyInit__gdalconst’:
#       extensions/gdalconst_wrap.c:3526:63: error: ‘GDT_UInt64’ undeclared (first use in this function); did you mean ‘GDT_UInt32’?
#        3526 |   SWIG_Python_SetConstant(d, "GDT_UInt64",SWIG_From_int((int)(GDT_UInt64)));
#             |                                                               ^~~~~~~~~~
#             |                                                               GDT_UInt32
#       extensions/gdalconst_wrap.c:3526:63: note: each undeclared identifier is reported only once for each function it appears in
#       extensions/gdalconst_wrap.c:3527:62: error: ‘GDT_Int64’ undeclared (first use in this function); did you mean ‘GDT_Int32’?
#        3527 |   SWIG_Python_SetConstant(d, "GDT_Int64",SWIG_From_int((int)(GDT_Int64)));
#             |                                                              ^~~~~~~~~
#             |                                                              GDT_Int32
#       extensions/gdalconst_wrap.c:3630:83: error: ‘GDAL_DMD_MULTIDIM_ARRAY_OPENOPTIONLIST’ undeclared (first use in this function); did you mean ‘GDAL_DMD_MULTIDIM_ARRAY_CREATIONOPTIONLIST’?
#        3630 |   SWIG_Python_SetConstant(d, "DMD_MULTIDIM_ARRAY_OPENOPTIONLIST",SWIG_FromCharPtr(GDAL_DMD_MULTIDIM_ARRAY_OPENOPTIONLIST));
#             |                                                                                   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                                                                                   GDAL_DMD_MULTIDIM_ARRAY_CREATIONOPTIONLIST
#       extensions/gdalconst_wrap.c:3637:81: error: ‘GDAL_DMD_CREATION_FIELD_DOMAIN_TYPES’ undeclared (first use in this function); did you mean ‘GDAL_DMD_CREATIONFIELDDATASUBTYPES’?
#        3637 |   SWIG_Python_SetConstant(d, "DMD_CREATION_FIELD_DOMAIN_TYPES",SWIG_FromCharPtr(GDAL_DMD_CREATION_FIELD_DOMAIN_TYPES));
#             |                                                                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                                                                                 GDAL_DMD_CREATIONFIELDDATASUBTYPES
#       extensions/gdalconst_wrap.c:3638:81: error: ‘GDAL_DMD_ALTER_GEOM_FIELD_DEFN_FLAGS’ undeclared (first use in this function)
#        3638 |   SWIG_Python_SetConstant(d, "DMD_ALTER_GEOM_FIELD_DEFN_FLAGS",SWIG_FromCharPtr(GDAL_DMD_ALTER_GEOM_FIELD_DEFN_FLAGS));
#             |                                                                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3639:76: error: ‘GDAL_DMD_SUPPORTED_SQL_DIALECTS’ undeclared (first use in this function)
#        3639 |   SWIG_Python_SetConstant(d, "DMD_SUPPORTED_SQL_DIALECTS",SWIG_FromCharPtr(GDAL_DMD_SUPPORTED_SQL_DIALECTS));
#             |                                                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3651:67: error: ‘GDAL_DCAP_CREATE_LAYER’ undeclared (first use in this function); did you mean ‘GDAL_DCAP_CREATECOPY’?
#        3651 |   SWIG_Python_SetConstant(d, "DCAP_CREATE_LAYER",SWIG_FromCharPtr(GDAL_DCAP_CREATE_LAYER));
#             |                                                                   ^~~~~~~~~~~~~~~~~~~~~~
#             |                                                                   GDAL_DCAP_CREATECOPY
#       extensions/gdalconst_wrap.c:3652:67: error: ‘GDAL_DCAP_DELETE_LAYER’ undeclared (first use in this function)
#        3652 |   SWIG_Python_SetConstant(d, "DCAP_DELETE_LAYER",SWIG_FromCharPtr(GDAL_DCAP_DELETE_LAYER));
#             |                                                                   ^~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3653:67: error: ‘GDAL_DCAP_CREATE_FIELD’ undeclared (first use in this function); did you mean ‘GDAL_DCAP_UNIQUE_FIELDS’?
#        3653 |   SWIG_Python_SetConstant(d, "DCAP_CREATE_FIELD",SWIG_FromCharPtr(GDAL_DCAP_CREATE_FIELD));
#             |                                                                   ^~~~~~~~~~~~~~~~~~~~~~
#             |                                                                   GDAL_DCAP_UNIQUE_FIELDS
#       extensions/gdalconst_wrap.c:3654:67: error: ‘GDAL_DCAP_DELETE_FIELD’ undeclared (first use in this function); did you mean ‘GDAL_DCAP_UNIQUE_FIELDS’?
#        3654 |   SWIG_Python_SetConstant(d, "DCAP_DELETE_FIELD",SWIG_FromCharPtr(GDAL_DCAP_DELETE_FIELD));
#             |                                                                   ^~~~~~~~~~~~~~~~~~~~~~
#             |                                                                   GDAL_DCAP_UNIQUE_FIELDS
#       extensions/gdalconst_wrap.c:3655:69: error: ‘GDAL_DCAP_REORDER_FIELDS’ undeclared (first use in this function); did you mean ‘GDAL_DCAP_UNIQUE_FIELDS’?
#        3655 |   SWIG_Python_SetConstant(d, "DCAP_REORDER_FIELDS",SWIG_FromCharPtr(GDAL_DCAP_REORDER_FIELDS));
#             |                                                                     ^~~~~~~~~~~~~~~~~~~~~~~~
#             |                                                                     GDAL_DCAP_UNIQUE_FIELDS
#       extensions/gdalconst_wrap.c:3656:76: error: ‘GDAL_DMD_ALTER_FIELD_DEFN_FLAGS’ undeclared (first use in this function)
#        3656 |   SWIG_Python_SetConstant(d, "DMD_ALTER_FIELD_DEFN_FLAGS",SWIG_FromCharPtr(GDAL_DMD_ALTER_FIELD_DEFN_FLAGS));
#             |                                                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3662:71: error: ‘GDAL_DCAP_CURVE_GEOMETRIES’ undeclared (first use in this function)
#        3662 |   SWIG_Python_SetConstant(d, "DCAP_CURVE_GEOMETRIES",SWIG_FromCharPtr(GDAL_DCAP_CURVE_GEOMETRIES));
#             |                                                                       ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3663:74: error: ‘GDAL_DCAP_MEASURED_GEOMETRIES’ undeclared (first use in this function); did you mean ‘GDAL_DCAP_FEATURE_STYLES’?
#        3663 |   SWIG_Python_SetConstant(d, "DCAP_MEASURED_GEOMETRIES",SWIG_FromCharPtr(GDAL_DCAP_MEASURED_GEOMETRIES));
#             |                                                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                                                                          GDAL_DCAP_FEATURE_STYLES
#       extensions/gdalconst_wrap.c:3664:67: error: ‘GDAL_DCAP_Z_GEOMETRIES’ undeclared (first use in this function)
#        3664 |   SWIG_Python_SetConstant(d, "DCAP_Z_GEOMETRIES",SWIG_FromCharPtr(GDAL_DCAP_Z_GEOMETRIES));
#             |                                                                   ^~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3665:68: error: ‘GDAL_DMD_GEOMETRY_FLAGS’ undeclared (first use in this function)
#        3665 |   SWIG_Python_SetConstant(d, "DMD_GEOMETRY_FLAGS",SWIG_FromCharPtr(GDAL_DMD_GEOMETRY_FLAGS));
#             |                                                                    ^~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3669:68: error: ‘GDAL_DCAP_FIELD_DOMAINS’ undeclared (first use in this function)
#        3669 |   SWIG_Python_SetConstant(d, "DCAP_FIELD_DOMAINS",SWIG_FromCharPtr(GDAL_DCAP_FIELD_DOMAINS));
#             |                                                                    ^~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3670:68: error: ‘GDAL_DCAP_RELATIONSHIPS’ undeclared (first use in this function)
#        3670 |   SWIG_Python_SetConstant(d, "DCAP_RELATIONSHIPS",SWIG_FromCharPtr(GDAL_DCAP_RELATIONSHIPS));
#             |                                                                    ^~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3671:79: error: ‘GDAL_DCAP_CREATE_RELATIONSHIP’ undeclared (first use in this function)
#        3671 |   SWIG_Python_SetConstant(d, "GDAL_DCAP_CREATE_RELATIONSHIP",SWIG_FromCharPtr(GDAL_DCAP_CREATE_RELATIONSHIP));
#             |                                                                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3672:79: error: ‘GDAL_DCAP_DELETE_RELATIONSHIP’ undeclared (first use in this function)
#        3672 |   SWIG_Python_SetConstant(d, "GDAL_DCAP_DELETE_RELATIONSHIP",SWIG_FromCharPtr(GDAL_DCAP_DELETE_RELATIONSHIP));
#             |                                                                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3673:79: error: ‘GDAL_DCAP_UPDATE_RELATIONSHIP’ undeclared (first use in this function)
#        3673 |   SWIG_Python_SetConstant(d, "GDAL_DCAP_UPDATE_RELATIONSHIP",SWIG_FromCharPtr(GDAL_DCAP_UPDATE_RELATIONSHIP));
#             |                                                                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3674:77: error: ‘GDAL_DMD_RELATIONSHIP_FLAGS’ undeclared (first use in this function)
#        3674 |   SWIG_Python_SetConstant(d, "GDAL_DMD_RELATIONSHIP_FLAGS",SWIG_FromCharPtr(GDAL_DMD_RELATIONSHIP_FLAGS));
#             |                                                                             ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3675:68: error: ‘GDAL_DCAP_RENAME_LAYERS’ undeclared (first use in this function)
#        3675 |   SWIG_Python_SetConstant(d, "DCAP_RENAME_LAYERS",SWIG_FromCharPtr(GDAL_DCAP_RENAME_LAYERS));
#             |                                                                    ^~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3729:67: error: ‘GRC_ONE_TO_ONE’ undeclared (first use in this function)
#        3729 |   SWIG_Python_SetConstant(d, "GRC_ONE_TO_ONE",SWIG_From_int((int)(GRC_ONE_TO_ONE)));
#             |                                                                   ^~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3730:68: error: ‘GRC_ONE_TO_MANY’ undeclared (first use in this function)
#        3730 |   SWIG_Python_SetConstant(d, "GRC_ONE_TO_MANY",SWIG_From_int((int)(GRC_ONE_TO_MANY)));
#             |                                                                    ^~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3731:68: error: ‘GRC_MANY_TO_ONE’ undeclared (first use in this function)
#        3731 |   SWIG_Python_SetConstant(d, "GRC_MANY_TO_ONE",SWIG_From_int((int)(GRC_MANY_TO_ONE)));
#             |                                                                    ^~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3732:69: error: ‘GRC_MANY_TO_MANY’ undeclared (first use in this function)
#        3732 |   SWIG_Python_SetConstant(d, "GRC_MANY_TO_MANY",SWIG_From_int((int)(GRC_MANY_TO_MANY)));
#             |                                                                     ^~~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3733:66: error: ‘GRT_COMPOSITE’ undeclared (first use in this function)
#        3733 |   SWIG_Python_SetConstant(d, "GRT_COMPOSITE",SWIG_From_int((int)(GRT_COMPOSITE)));
#             |                                                                  ^~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3734:68: error: ‘GRT_ASSOCIATION’ undeclared (first use in this function)
#        3734 |   SWIG_Python_SetConstant(d, "GRT_ASSOCIATION",SWIG_From_int((int)(GRT_ASSOCIATION)));
#             |                                                                    ^~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3735:68: error: ‘GRT_AGGREGATION’ undeclared (first use in this function)
#        3735 |   SWIG_Python_SetConstant(d, "GRT_AGGREGATION",SWIG_From_int((int)(GRT_AGGREGATION)));
#             |                                                                    ^~~~~~~~~~~~~~~
#       extensions/gdalconst_wrap.c:3738:3: warning: ‘PyEval_InitThreads’ is deprecated [-Wdeprecated-declarations]
#        3738 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/gdalconst_wrap.c:156:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       building 'osgeo._gdal_array' extension
#       gcc -pthread -B /home/danny/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/danny/anaconda3/include -I/home/danny/anaconda3/include -fPIC -O2 -isystem /home/danny/anaconda3/include -fPIC -I/home/danny/anaconda3/include/python3.9 -I/home/danny/anaconda3/lib/python3.9/site-packages/numpy/core/include -I/home/danny/anaconda3/include -c extensions/gdal_array_wrap.cpp -o build/temp.linux-x86_64-cpython-39/extensions/gdal_array_wrap.o -I/home/danny/anaconda3/include
#       extensions/gdal_array_wrap.cpp:3237:10: fatal error: ogr_recordbatch.h: No existe el archivo o el directorio
#        3237 | #include "ogr_recordbatch.h"
#             |          ^~~~~~~~~~~~~~~~~~~
#       compilation terminated.
#       extensions/osr_wrap.cpp: In function ‘OGRErr OSRSpatialReferenceShadow_StripVertical(OSRSpatialReferenceShadow*)’:
#       extensions/osr_wrap.cpp:4049:12: error: ‘OSRStripVertical’ was not declared in this scope; did you mean ‘OSRIsVertical’?
#        4049 |     return OSRStripVertical(self);
#             |            ^~~~~~~~~~~~~~~~
#             |            OSRIsVertical
#       extensions/gdal_wrap.cpp: In function ‘int getAlignment(GDALDataType)’:
#       extensions/gdal_wrap.cpp:2952:14: error: ‘GDT_Int64’ was not declared in this scope; did you mean ‘GDT_Int32’?
#        2952 |         case GDT_Int64:
#             |              ^~~~~~~~~
#             |              GDT_Int32
#       extensions/gdal_wrap.cpp:2953:14: error: ‘GDT_UInt64’ was not declared in this scope; did you mean ‘GDT_UInt32’?
#        2953 |         case GDT_UInt64:
#             |              ^~~~~~~~~~
#             |              GDT_UInt32
#       extensions/gdal_wrap.cpp: In function ‘void wrapper_VSISetCredential(const char*, const char*, const char*)’:
#       extensions/gdal_wrap.cpp:4020:5: error: ‘VSISetPathSpecificOption’ was not declared in this scope
#        4020 |     VSISetPathSpecificOption(pszPathPrefix, pszKey, pszValue);
#             |     ^~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘const char* wrapper_VSIGetCredential(const char*, const char*, const char*)’:
#       extensions/gdal_wrap.cpp:4025:12: error: ‘VSIGetPathSpecificOption’ was not declared in this scope
#        4025 |     return VSIGetPathSpecificOption( pszPathPrefix, pszKey, pszDefault );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gnm_wrap.cpp: In function ‘PyObject* PyInit__gnm()’:
#       extensions/gnm_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/gnm_wrap.cpp:6539:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#        6539 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/gnm_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘const char* wrapper_VSIGetPathSpecificOption(const char*, const char*, const char*)’:
#       extensions/gdal_wrap.cpp:4030:12: error: ‘VSIGetPathSpecificOption’ was not declared in this scope; did you mean ‘wrapper_VSIGetPathSpecificOption’?
#        4030 |     return VSIGetPathSpecificOption( pszPathPrefix, pszKey, pszDefault );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~
#             |            wrapper_VSIGetPathSpecificOption
#       extensions/gnm_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/gnm_wrap.cpp:6539:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#        6539 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/gnm_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘void wrapper_VSIClearCredentials(const char*)’:
#       extensions/gdal_wrap.cpp:4036:5: error: ‘VSIClearPathSpecificOptions’ was not declared in this scope
#        4036 |     VSIClearPathSpecificOptions( pszPathPrefix );
#             |     ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘void wrapper_VSIClearPathSpecificOptions(const char*)’:
#       extensions/gdal_wrap.cpp:4040:5: error: ‘VSIClearPathSpecificOptions’ was not declared in this scope; did you mean ‘wrapper_VSIClearPathSpecificOptions’?
#        4040 |     VSIClearPathSpecificOptions( pszPathPrefix );
#             |     ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |     wrapper_VSIClearPathSpecificOptions
#       extensions/gdal_wrap.cpp: In function ‘int GDALDatasetShadow_BuildOverviews(GDALDatasetShadow*, const char*, int, int*, GDALProgressFunc, void*, char**)’:
#       extensions/gdal_wrap.cpp:4718:12: error: ‘GDALBuildOverviewsEx’ was not declared in this scope; did you mean ‘GDALBuildOverviews’?
#        4718 |     return GDALBuildOverviewsEx(  self,
#             |            ^~~~~~~~~~~~~~~~~~~~
#             |            GDALBuildOverviews
#       extensions/gdal_wrap.cpp: In function ‘char** GDALDatasetShadow_GetFieldDomainNames(GDALDatasetShadow*, char**)’:
#       extensions/gdal_wrap.cpp:5096:12: error: ‘GDALDatasetGetFieldDomainNames’ was not declared in this scope; did you mean ‘GDALDatasetGetFieldDomain’?
#        5096 |     return GDALDatasetGetFieldDomainNames(self, options);
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALDatasetGetFieldDomain
#       extensions/gdal_wrap.cpp: In function ‘bool GDALDatasetShadow_DeleteFieldDomain(GDALDatasetShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:5105:14: error: ‘GDALDatasetDeleteFieldDomain’ was not declared in this scope; did you mean ‘GDALDatasetGetFieldDomain’?
#        5105 |       return GDALDatasetDeleteFieldDomain(self, name, NULL);
#             |              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALDatasetGetFieldDomain
#       extensions/gdal_wrap.cpp: In function ‘bool GDALDatasetShadow_UpdateFieldDomain(GDALDatasetShadow*, OGRFieldDomainShadow*)’:
#       extensions/gdal_wrap.cpp:5108:14: error: ‘GDALDatasetUpdateFieldDomain’ was not declared in this scope; did you mean ‘GDALDatasetAddFieldDomain’?
#        5108 |       return GDALDatasetUpdateFieldDomain(self, (OGRFieldDomainH)fieldDomain, NULL);
#             |              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALDatasetAddFieldDomain
#       extensions/gdal_wrap.cpp: In function ‘char** GDALDatasetShadow_GetRelationshipNames(GDALDatasetShadow*, char**)’:
#       extensions/gdal_wrap.cpp:5111:12: error: ‘GDALDatasetGetRelationshipNames’ was not declared in this scope; did you mean ‘GDALDatasetShadow_GetRelationshipNames’?
#        5111 |     return GDALDatasetGetRelationshipNames(self, options);
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALDatasetShadow_GetRelationshipNames
#       extensions/gdal_wrap.cpp: In function ‘GDALRelationshipShadow* GDALDatasetShadow_GetRelationship(GDALDatasetShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:5114:38: error: ‘GDALDatasetGetRelationship’ was not declared in this scope; did you mean ‘GDALDatasetShadow_GetRelationship’?
#        5114 |     return (GDALRelationshipShadow*) GDALDatasetGetRelationship(self, name);
#             |                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                                      GDALDatasetShadow_GetRelationship
#       extensions/gdal_wrap.cpp: In function ‘bool GDALDatasetShadow_AddRelationship(GDALDatasetShadow*, GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:5117:48: error: ‘GDALRelationshipH’ was not declared in this scope; did you mean ‘relationship’?
#        5117 |       return GDALDatasetAddRelationship(self, (GDALRelationshipH)relationship, NULL);
#             |                                                ^~~~~~~~~~~~~~~~~
#             |                                                relationship
#       extensions/gdal_wrap.cpp:5117:14: error: ‘GDALDatasetAddRelationship’ was not declared in this scope; did you mean ‘GDALDatasetShadow_AddRelationship’?
#        5117 |       return GDALDatasetAddRelationship(self, (GDALRelationshipH)relationship, NULL);
#             |              ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALDatasetShadow_AddRelationship
#       extensions/gdal_wrap.cpp: In function ‘bool GDALDatasetShadow_DeleteRelationship(GDALDatasetShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:5120:14: error: ‘GDALDatasetDeleteRelationship’ was not declared in this scope; did you mean ‘GDALDatasetShadow_DeleteRelationship’?
#        5120 |       return GDALDatasetDeleteRelationship(self, name, NULL);
#             |              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALDatasetShadow_DeleteRelationship
#       extensions/gdal_wrap.cpp: In function ‘bool GDALDatasetShadow_UpdateRelationship(GDALDatasetShadow*, GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:5123:51: error: ‘GDALRelationshipH’ was not declared in this scope; did you mean ‘relationship’?
#        5123 |       return GDALDatasetUpdateRelationship(self, (GDALRelationshipH)relationship, NULL);
#             |                                                   ^~~~~~~~~~~~~~~~~
#             |                                                   relationship
#       extensions/gdal_wrap.cpp:5123:14: error: ‘GDALDatasetUpdateRelationship’ was not declared in this scope; did you mean ‘GDALDatasetShadow_UpdateRelationship’?
#        5123 |       return GDALDatasetUpdateRelationship(self, (GDALRelationshipH)relationship, NULL);
#             |              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALDatasetShadow_UpdateRelationship
#       extensions/gdal_wrap.cpp: In function ‘void GDALMDArrayHS_GetNoDataValueAsInt64(GDALMDArrayHS*, GIntBig*, int*)’:
#       extensions/gdal_wrap.cpp:5897:12: error: ‘GDALMDArrayGetNoDataValueAsInt64’ was not declared in this scope; did you mean ‘GDALMDArrayHS_GetNoDataValueAsInt64’?
#        5897 |     *val = GDALMDArrayGetNoDataValueAsInt64( self, hasval );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALMDArrayHS_GetNoDataValueAsInt64
#       extensions/gdal_wrap.cpp: In function ‘void GDALMDArrayHS_GetNoDataValueAsUInt64(GDALMDArrayHS*, GUIntBig*, int*)’:
#       extensions/gdal_wrap.cpp:5900:12: error: ‘GDALMDArrayGetNoDataValueAsUInt64’ was not declared in this scope; did you mean ‘GDALMDArrayHS_GetNoDataValueAsUInt64’?
#        5900 |     *val = GDALMDArrayGetNoDataValueAsUInt64( self, hasval );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALMDArrayHS_GetNoDataValueAsUInt64
#       extensions/gdal_wrap.cpp: In function ‘CPLErr GDALMDArrayHS_SetNoDataValueInt64(GDALMDArrayHS*, GIntBig)’:
#       extensions/gdal_wrap.cpp:5926:12: error: ‘GDALMDArraySetNoDataValueAsInt64’ was not declared in this scope; did you mean ‘GDALMDArrayHS_GetNoDataValueAsInt64’?
#        5926 |     return GDALMDArraySetNoDataValueAsInt64( self, v ) ? CE_None : CE_Failure;
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALMDArrayHS_GetNoDataValueAsInt64
#       extensions/gdal_wrap.cpp: In function ‘CPLErr GDALMDArrayHS_SetNoDataValueUInt64(GDALMDArrayHS*, GUIntBig)’:
#       extensions/gdal_wrap.cpp:5929:12: error: ‘GDALMDArraySetNoDataValueAsUInt64’ was not declared in this scope; did you mean ‘GDALMDArrayHS_GetNoDataValueAsUInt64’?
#        5929 |     return GDALMDArraySetNoDataValueAsUInt64( self, v ) ? CE_None : CE_Failure;
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALMDArrayHS_GetNoDataValueAsUInt64
#       extensions/gdal_wrap.cpp: In function ‘void GDALRasterBandShadow_GetNoDataValueAsInt64(GDALRasterBandShadow*, GIntBig*, int*)’:
#       extensions/gdal_wrap.cpp:6339:12: error: ‘GDALGetRasterNoDataValueAsInt64’ was not declared in this scope; did you mean ‘GDALGetRasterNoDataValue’?
#        6339 |     *val = GDALGetRasterNoDataValueAsInt64( self, hasval );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALGetRasterNoDataValue
#       extensions/gdal_wrap.cpp: In function ‘void GDALRasterBandShadow_GetNoDataValueAsUInt64(GDALRasterBandShadow*, GUIntBig*, int*)’:
#       extensions/gdal_wrap.cpp:6342:12: error: ‘GDALGetRasterNoDataValueAsUInt64’ was not declared in this scope; did you mean ‘GDALGetRasterNoDataValue’?
#        6342 |     *val = GDALGetRasterNoDataValueAsUInt64( self, hasval );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALGetRasterNoDataValue
#       extensions/gdal_wrap.cpp: In function ‘CPLErr GDALRasterBandShadow_SetNoDataValueAsInt64(GDALRasterBandShadow*, GIntBig)’:
#       extensions/gdal_wrap.cpp:6348:12: error: ‘GDALSetRasterNoDataValueAsInt64’ was not declared in this scope; did you mean ‘GDALSetRasterNoDataValue’?
#        6348 |     return GDALSetRasterNoDataValueAsInt64( self, v );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALSetRasterNoDataValue
#       extensions/gdal_wrap.cpp: In function ‘CPLErr GDALRasterBandShadow_SetNoDataValueAsUInt64(GDALRasterBandShadow*, GUIntBig)’:
#       extensions/gdal_wrap.cpp:6351:12: error: ‘GDALSetRasterNoDataValueAsUInt64’ was not declared in this scope; did you mean ‘GDALSetRasterNoDataValue’?
#        6351 |     return GDALSetRasterNoDataValueAsUInt64( self, v );
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |            GDALSetRasterNoDataValue
#       extensions/gdal_wrap.cpp: In function ‘void GDALRasterBandShadow_ComputeRasterMinMax(GDALRasterBandShadow*, double*, int*, bool, bool)’:
#       extensions/gdal_wrap.cpp:6412:67: error: no match for ‘operator==’ (operand types are ‘void’ and ‘CPLErr’)
#        6412 |     *isvalid = GDALComputeRasterMinMax( self, approx_ok, argout ) == CE_None;
#             |                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^~ ~~~~~~~
#             |                                       |                              |
#             |                                       void                           CPLErr
#       extensions/osr_wrap.cpp: In function ‘PyObject* PyInit__osr()’:
#       extensions/osr_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/osr_wrap.cpp:19226:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#       19226 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/osr_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       extensions/osr_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/osr_wrap.cpp:19226:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#       19226 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/osr_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘bool GDALRasterBandShadow_IsMaskBand(GDALRasterBandShadow*)’:
#       extensions/gdal_wrap.cpp:6469:14: error: ‘GDALIsMaskBand’ was not declared in this scope; did you mean ‘GDALGetMaskBand’?
#        6469 |       return GDALIsMaskBand( self );
#             |              ^~~~~~~~~~~~~~
#             |              GDALGetMaskBand
#       extensions/gdal_wrap.cpp: At global scope:
#       extensions/gdal_wrap.cpp:6788:133: error: ‘GDALRelationshipCardinality’ has not been declared
#        6788 | SWIGINTERN GDALRelationshipShadow *new_GDALRelationshipShadow(char const *name,char const *leftTableName,char const *rightTableName,GDALRelationshipCardinality cardinality){
#             |                                                                                                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘GDALRelationshipShadow* new_GDALRelationshipShadow(const char*, const char*, const char*, int)’:
#       extensions/gdal_wrap.cpp:6790:9: error: ‘GDALRelationshipCreate’ was not declared in this scope; did you mean ‘GDALRelationshipShadow’?
#        6790 |         GDALRelationshipCreate(name,
#             |         ^~~~~~~~~~~~~~~~~~~~~~
#             |         GDALRelationshipShadow
#       extensions/gdal_wrap.cpp: In function ‘void delete_GDALRelationshipShadow(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6796:9: error: ‘GDALDestroyRelationship’ was not declared in this scope
#        6796 |         GDALDestroyRelationship(self);
#             |         ^~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetName(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6799:16: error: ‘GDALRelationshipGetName’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetName’?
#        6799 |         return GDALRelationshipGetName( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetName
#       extensions/gdal_wrap.cpp: At global scope:
#       extensions/gdal_wrap.cpp:6801:12: error: ‘GDALRelationshipCardinality’ does not name a type
#        6801 | SWIGINTERN GDALRelationshipCardinality GDALRelationshipShadow_GetCardinality(GDALRelationshipShadow *self){
#             |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetLeftTableName(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6805:16: error: ‘GDALRelationshipGetLeftTableName’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetLeftTableName’?
#        6805 |         return GDALRelationshipGetLeftTableName( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetLeftTableName
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetRightTableName(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6808:16: error: ‘GDALRelationshipGetRightTableName’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetRightTableName’?
#        6808 |         return GDALRelationshipGetRightTableName( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetRightTableName
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetMappingTableName(GDALRelationshipShadow*)’:
# ...
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetRightTableFields(GDALRelationshipShadow*, char**)’:
#       extensions/gdal_wrap.cpp:6826:13: error: ‘GDALRelationshipSetRightTableFields’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetRightTableFields’?
#        6826 |             GDALRelationshipSetRightTableFields(self, pFields);
#             |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |             GDALRelationshipShadow_SetRightTableFields
#       extensions/gdal_wrap.cpp: In function ‘char** GDALRelationshipShadow_GetLeftMappingTableFields(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6829:20: error: ‘GDALRelationshipGetLeftMappingTableFields’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetLeftMappingTableFields’?
#        6829 |             return GDALRelationshipGetLeftMappingTableFields(self);
#             |                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                    GDALRelationshipShadow_GetLeftMappingTableFields
#       extensions/gdal_wrap.cpp: In function ‘char** GDALRelationshipShadow_GetRightMappingTableFields(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6832:20: error: ‘GDALRelationshipGetRightMappingTableFields’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetRightMappingTableFields’?
#        6832 |             return GDALRelationshipGetRightMappingTableFields(self);
#             |                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                    GDALRelationshipShadow_GetRightMappingTableFields
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetLeftMappingTableFields(GDALRelationshipShadow*, char**)’:
#       extensions/gdal_wrap.cpp:6835:11: error: ‘GDALRelationshipSetLeftMappingTableFields’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetLeftMappingTableFields’?
#        6835 |           GDALRelationshipSetLeftMappingTableFields(self, pFields);
#             |           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |           GDALRelationshipShadow_SetLeftMappingTableFields
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetRightMappingTableFields(GDALRelationshipShadow*, char**)’:
#       extensions/gdal_wrap.cpp:6838:11: error: ‘GDALRelationshipSetRightMappingTableFields’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetRightMappingTableFields’?
#        6838 |           GDALRelationshipSetRightMappingTableFields(self, pFields);
#             |           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |           GDALRelationshipShadow_SetRightMappingTableFields
#       extensions/gdal_wrap.cpp: At global scope:
#       extensions/gdal_wrap.cpp:6840:12: error: ‘GDALRelationshipType’ does not name a type; did you mean ‘GDALRelationshipShadow’?
#        6840 | SWIGINTERN GDALRelationshipType GDALRelationshipShadow_GetType(GDALRelationshipShadow *self){
#             |            ^~~~~~~~~~~~~~~~~~~~
#             |            GDALRelationshipShadow
#       extensions/gdal_wrap.cpp:6843:77: error: ‘GDALRelationshipType’ has not been declared
#        6843 | SWIGINTERN void GDALRelationshipShadow_SetType(GDALRelationshipShadow *self,GDALRelationshipType type){
#             |                                                                             ^~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetType(GDALRelationshipShadow*, int)’:
#       extensions/gdal_wrap.cpp:6844:14: error: ‘GDALRelationshipSetType’ was not declared in this scope; did you mean ‘GDALRelationshipShadow’?
#        6844 |       return GDALRelationshipSetType( self, type );
#             |              ^~~~~~~~~~~~~~~~~~~~~~~
#             |              GDALRelationshipShadow
#       extensions/gdal_wrap.cpp:6844:50: error: return-statement with a value, in function returning ‘void’ [-fpermissive]
#        6844 |       return GDALRelationshipSetType( self, type );
#             |                                                  ^
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetForwardPathLabel(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6847:16: error: ‘GDALRelationshipGetForwardPathLabel’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetForwardPathLabel’?
#        6847 |         return GDALRelationshipGetForwardPathLabel( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetForwardPathLabel
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetForwardPathLabel(GDALRelationshipShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:6850:9: error: ‘GDALRelationshipSetForwardPathLabel’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetForwardPathLabel’?
#        6850 |         GDALRelationshipSetForwardPathLabel( self, pszLabel );
#             |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |         GDALRelationshipShadow_SetForwardPathLabel
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetBackwardPathLabel(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6853:16: error: ‘GDALRelationshipGetBackwardPathLabel’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetBackwardPathLabel’?
#        6853 |         return GDALRelationshipGetBackwardPathLabel( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetBackwardPathLabel
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetBackwardPathLabel(GDALRelationshipShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:6856:9: error: ‘GDALRelationshipSetBackwardPathLabel’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetBackwardPathLabel’?
#        6856 |         GDALRelationshipSetBackwardPathLabel( self, pszLabel );
#             |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |         GDALRelationshipShadow_SetBackwardPathLabel
#       extensions/gdal_wrap.cpp: In function ‘const char* GDALRelationshipShadow_GetRelatedTableType(GDALRelationshipShadow*)’:
#       extensions/gdal_wrap.cpp:6859:16: error: ‘GDALRelationshipGetRelatedTableType’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_GetRelatedTableType’?
#        6859 |         return GDALRelationshipGetRelatedTableType( self );
#             |                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                GDALRelationshipShadow_GetRelatedTableType
#       extensions/gdal_wrap.cpp: In function ‘void GDALRelationshipShadow_SetRelatedTableType(GDALRelationshipShadow*, const char*)’:
#       extensions/gdal_wrap.cpp:6862:9: error: ‘GDALRelationshipSetRelatedTableType’ was not declared in this scope; did you mean ‘GDALRelationshipShadow_SetRelatedTableType’?
#        6862 |         GDALRelationshipSetRelatedTableType( self, pszType );
#             |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |         GDALRelationshipShadow_SetRelatedTableType
#       extensions/gdal_wrap.cpp: In function ‘PyObject* _wrap_SetPathSpecificOption(PyObject*, PyObject*)’:
#       extensions/gdal_wrap.cpp:10669:7: error: ‘VSISetPathSpecificOption’ was not declared in this scope; did you mean ‘_wrap_SetPathSpecificOption’?
#       10669 |       VSISetPathSpecificOption((char const *)arg1,(char const *)arg2,(char const *)arg3);
#             |       ^~~~~~~~~~~~~~~~~~~~~~~~
#             |       _wrap_SetPathSpecificOption
#       extensions/gdal_wrap.cpp: In function ‘PyObject* _wrap_new_Relationship(PyObject*, PyObject*)’:
#       extensions/gdal_wrap.cpp:36620:3: error: ‘GDALRelationshipCardinality’ was not declared in this scope
#       36620 |   GDALRelationshipCardinality arg4 ;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp:36655:3: error: ‘arg4’ was not declared in this scope; did you mean ‘arg3’?
#       36655 |   arg4 = static_cast< GDALRelationshipCardinality >(val4);
#             |   ^~~~
#             |   arg3
#       extensions/gdal_wrap.cpp:36655:23: error: ‘GDALRelationshipCardinality’ does not name a type
#       36655 |   arg4 = static_cast< GDALRelationshipCardinality >(val4);
#             |                       ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp: In function ‘PyObject* _wrap_Relationship_GetCardinality(PyObject*, PyObject*)’:
#       extensions/gdal_wrap.cpp:36780:3: error: ‘GDALRelationshipCardinality’ was not declared in this scope; did you mean ‘_wrap_Relationship_GetCardinality’?
#       36780 |   GDALRelationshipCardinality result;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |   _wrap_Relationship_GetCardinality
#       extensions/gdal_wrap.cpp:36795:7: error: ‘result’ was not declared in this scope
#       36795 |       result = (GDALRelationshipCardinality)GDALRelationshipShadow_GetCardinality(arg1);
#             |       ^~~~~~
#       extensions/gdal_wrap.cpp:36807:48: error: ‘result’ was not declared in this scope
#       36807 |   resultobj = SWIG_From_int(static_cast< int >(result));
#             |                                                ^~~~~~
#       extensions/gdal_wrap.cpp: In function ‘PyObject* _wrap_Relationship_GetType(PyObject*, PyObject*)’:
#       extensions/gdal_wrap.cpp:37468:3: error: ‘GDALRelationshipType’ was not declared in this scope; did you mean ‘GDALRelationshipShadow’?
#       37468 |   GDALRelationshipType result;
#             |   ^~~~~~~~~~~~~~~~~~~~
#             |   GDALRelationshipShadow
#       extensions/gdal_wrap.cpp:37483:7: error: ‘result’ was not declared in this scope
#       37483 |       result = (GDALRelationshipType)GDALRelationshipShadow_GetType(arg1);
#             |       ^~~~~~
#       extensions/gdal_wrap.cpp:37495:48: error: ‘result’ was not declared in this scope
#       37495 |   resultobj = SWIG_From_int(static_cast< int >(result));
#             |                                                ^~~~~~
#       extensions/gdal_wrap.cpp: In function ‘PyObject* _wrap_Relationship_SetType(PyObject*, PyObject*)’:
#       extensions/gdal_wrap.cpp:37506:3: error: ‘GDALRelationshipType’ was not declared in this scope; did you mean ‘GDALRelationshipShadow’?
#       37506 |   GDALRelationshipType arg2 ;
#             |   ^~~~~~~~~~~~~~~~~~~~
#             |   GDALRelationshipShadow
#       extensions/gdal_wrap.cpp:37523:3: error: ‘arg2’ was not declared in this scope; did you mean ‘arg1’?
#       37523 |   arg2 = static_cast< GDALRelationshipType >(val2);
#             |   ^~~~
#             |   arg1
#       extensions/gdal_wrap.cpp:37523:23: error: ‘GDALRelationshipType’ does not name a type; did you mean ‘GDALRelationshipShadow’?
#       37523 |   arg2 = static_cast< GDALRelationshipType >(val2);
#             |                       ^~~~~~~~~~~~~~~~~~~~
#             |                       GDALRelationshipShadow
#       g++ -pthread -B /home/danny/anaconda3/compiler_compat -shared -Wl,-rpath,/home/danny/anaconda3/lib -Wl,-rpath-link,/home/danny/anaconda3/lib -L/home/danny/anaconda3/lib -L/home/danny/anaconda3/lib -Wl,-rpath,/home/danny/anaconda3/lib -Wl,-rpath-link,/home/danny/anaconda3/lib -L/home/danny/anaconda3/lib build/temp.linux-x86_64-cpython-39/extensions/gnm_wrap.o -L/home/danny/anaconda3/lib -lgdal -o build/lib.linux-x86_64-cpython-39/osgeo/_gnm.cpython-39-x86_64-linux-gnu.so
#       extensions/gdal_wrap.cpp: In function ‘PyObject* PyInit__gdal()’:
#       extensions/gdal_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/gdal_wrap.cpp:48265:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#       48265 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/gdal_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       extensions/gdal_wrap.cpp:982:65: warning: ‘void PyEval_InitThreads()’ is deprecated [-Wdeprecated-declarations]
#         982 | #     define SWIG_PYTHON_INITIALIZE_THREADS  PyEval_InitThreads()
#             |                                                                 ^
#       extensions/gdal_wrap.cpp:48265:3: note: in expansion of macro ‘SWIG_PYTHON_INITIALIZE_THREADS’
#       48265 |   SWIG_PYTHON_INITIALIZE_THREADS;
#             |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /home/danny/anaconda3/include/python3.9/Python.h:140,
#                        from extensions/gdal_wrap.cpp:180:
#       /home/danny/anaconda3/include/python3.9/ceval.h:130:37: note: declared here
#         130 | Py_DEPRECATED(3.9) PyAPI_FUNC(void) PyEval_InitThreads(void);
#             |                                     ^~~~~~~~~~~~~~~~~~
#       error: command '/usr/bin/gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Rolling back uninstall of GDAL
#   Moving to /home/danny/anaconda3/bin/__pycache__/
#    from /home/danny/anaconda3/bin/~_pycache__
#   Moving to /home/danny/anaconda3/bin/gdal2tiles.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal2tiles.py
#   Moving to /home/danny/anaconda3/bin/gdal2xyz.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal2xyz.py
#   Moving to /home/danny/anaconda3/bin/gdal_calc.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_calc.py
#   Moving to /home/danny/anaconda3/bin/gdal_edit.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_edit.py
#   Moving to /home/danny/anaconda3/bin/gdal_fillnodata.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_fillnodata.py
#   Moving to /home/danny/anaconda3/bin/gdal_merge.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_merge.py
#   Moving to /home/danny/anaconda3/bin/gdal_pansharpen.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_pansharpen.py
#   Moving to /home/danny/anaconda3/bin/gdal_polygonize.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_polygonize.py
#   Moving to /home/danny/anaconda3/bin/gdal_proximity.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_proximity.py
#   Moving to /home/danny/anaconda3/bin/gdal_retile.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_retile.py
#   Moving to /home/danny/anaconda3/bin/gdal_sieve.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdal_sieve.py
#   Moving to /home/danny/anaconda3/bin/gdalattachpct.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdalattachpct.py
#   Moving to /home/danny/anaconda3/bin/gdalcompare.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdalcompare.py
#   Moving to /home/danny/anaconda3/bin/gdalmove.py
#    from /tmp/pip-uninstall-cc8hv1l5/gdalmove.py
#   Moving to /home/danny/anaconda3/bin/ogrmerge.py
#    from /tmp/pip-uninstall-cc8hv1l5/ogrmerge.py
#   Moving to /home/danny/anaconda3/bin/pct2rgb.py
#    from /tmp/pip-uninstall-cc8hv1l5/pct2rgb.py
#   Moving to /home/danny/anaconda3/bin/rgb2pct.py
#    from /tmp/pip-uninstall-cc8hv1l5/rgb2pct.py
#   Moving to /home/danny/anaconda3/lib/python3.9/site-packages/GDAL-3.3.2.dist-info/
#    from /home/danny/anaconda3/lib/python3.9/site-packages/~DAL-3.3.2.dist-info
#   Moving to /home/danny/anaconda3/lib/python3.9/site-packages/osgeo/
#    from /home/danny/anaconda3/lib/python3.9/site-packages/~sgeo
#   Moving to /home/danny/anaconda3/lib/python3.9/site-packages/osgeo_utils/
#    from /home/danny/anaconda3/lib/python3.9/site-packages/~sgeo_utils
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> gdal
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Note: you may need to restart the kernel to use updated packages.

# %%
from osgeo import gdal
import tifffile
from skimage.transform import resize
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/osgeo/__init__.py in swig_import_helper()
#      20     try:
# ---> 21         return importlib.import_module(mname)
#      22     except ImportError:
#
# ~/anaconda3/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in module_from_spec(spec)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap_external.py in create_module(self, spec)
#
# ~/anaconda3/lib/python3.9/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ImportError: libtiledb.so.2.2: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_33259/3368964980.py in <module>
# ----> 1 from osgeo import gdal
#       2 import tifffile
#       3 from skimage.transform import resize
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ~/anaconda3/lib/python3.9/site-packages/osgeo/__init__.py in <module>
#      35
#      36
# ---> 37 _gdal = swig_import_helper()
#      38 del swig_import_helper
#      39
#
# ~/anaconda3/lib/python3.9/site-packages/osgeo/__init__.py in swig_import_helper()
#      32                 traceback_string = ''.join(traceback.format_exception(*sys.exc_info()))
#      33                 raise ImportError(traceback_string + '\n' + msg)
# ---> 34         return importlib.import_module('_gdal')
#      35
#      36
#
# ~/anaconda3/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ModuleNotFoundError: No module named '_gdal'

# %%
clorofila_model = load_model('modelo_clorofila.h5')
altura_model = load_model('modelo_altura.h5')

ALTURA_MAX = 266.80
ALTURA_MIN = 0.0

CLOROFILA_MAX = 980.993
CLOROFILA_MIN = 0.0

# %%
def estandarizar_bandas(img):
    banda1, banda2, banda3, banda4 = np.moveaxis(img, 2, 0)
    bandas = [banda1, banda2, banda3, banda4]
    bandas_norm = []
    for banda in bandas:
        mean = banda.mean()
        std = banda.std()
        banda = (banda-mean)/std
        bandas_norm.append(banda)
    img_norm = np.array(bandas_norm)
    img_norm = np.moveaxis(bandas_norm, 0, 2)
    return img_norm

# %%
def recortar(img, h, w):
    cropped_images = []
    for r in range(h):
        for c in range(w):
            i1 = int(r*(img.shape[0]/h))
            i2 = int((r+1)*(img.shape[0]/h))
            
            j1 = int(c*(img.shape[1]/w))
            j2 = int((c+1)*(img.shape[1]/w))
            
            im = img[i1:i2, j1:j2]
            cropped_images.append(im)
    return cropped_images

# %%
def write_geotiff(filename, arr, in_ds):
    if arr.dtype == np.float32:
        arr_type = gdal.GDT_Float32
    else:
        arr_type = gdal.GDT_Int32

    driver = gdal.GetDriverByName("GTiff")
    out_ds = driver.Create(filename, arr.shape[1], arr.shape[0], 1, arr_type)
    out_ds.SetProjection(in_ds.GetProjection())
    out_ds.SetGeoTransform(in_ds.GetGeoTransform())
    band = out_ds.GetRasterBand(1)
    band.WriteArray(arr)
    band.FlushCache()
    band.ComputeStatistics(False)

# %%
def predecir(input_tif_path):
    tif = tifffile.imread(input_tif_path)
    resized_tif = resize(tif, (2240, 2240))
    norm_tif = estandarizar_bandas(resized_tif)
    cropped_tif = recortar(norm_tif, 10, 10)
    X = np.array(cropped_tif)
    clorofila_pred = clorofila_model.predict(X)
    altura_pred = altura_model.predict(X)
    altura_results = []
    clorofila_results = []
    for i in range(100):
        img_altura = altura_pred[i]
        img_altura = np.argmax(img_altura, axis=-1)
        altura_results.append(img_altura)
        img_clorofila = clorofila_pred[i]
        img_clorofila = np.argmax(img_clorofila, axis=-1)  
        clorofila_results.append(img_clorofila)

    return clorofila_results, altura_results

# %%
def guardar_tif(results, output_path, input_tif_path, v_max, v_min):

    fragments = []
    for i in range(10):
        initial = i*10
        final = (i+1)*10
        fragment = np.concatenate(results[initial:final], axis=1)
        fragments.append(fragment)

    img = np.concatenate(fragments)
    ds = gdal.Open(input_tif_path)
    array = ds.ReadAsArray()
    x, y = array.shape[1], array.shape[2]
    resized_img = resize(img, (x, y))
    scaled_img = resized_img*(v_max-v_min) + v_min
    write_geotiff(output_path, scaled_img, ds)

# %%
clorofila_pred, altura_pred = predecir('input.tif')
guardar_tif(clorofila_pred, 'clorofila.tif', 'input.tif', CLOROFILA_MAX, CLOROFILA_MIN)
guardar_tif(altura_pred, 'altura.tif', 'input.tif', ALTURA_MAX, ALTURA_MIN)
